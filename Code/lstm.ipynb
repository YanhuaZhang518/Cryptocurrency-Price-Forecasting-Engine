# %% [markdown]
# <a href="https://colab.research.google.com/github/WenyiYao/cryptocurrency/blob/main/lstm_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy
import matplotlib.pyplot as plt
from pandas import read_csv
import math
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import TimeDistributed
from tensorflow.keras.callbacks import EarlyStopping
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
import os
import pandas as pd
import numpy as np

# %%
df = pd.read_json('USDC-ETH.json')
df.head()
# Out:
#                                                  id         high          low  \
# 0  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19251  1483.170696  1396.900687
# 1  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19252  1476.144985  1402.098845
# 2  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19253  1469.421851  1324.864844
# 3  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19254  1392.051034  1274.907911
# 4  0x88e6a0c2ddd26feeb64f039a2c41296fcb3f5640-19255  1383.911802  1313.997663
#
#          tvlUSD  txCount     volumeUSD       date         open    tick  \
# 0  2.517911e+08    11053  4.784684e+08 2022-09-16  1472.111248  203641
# 1  2.666791e+08     9014  2.088181e+08 2022-09-17  1433.463152  203394
# 2  2.485486e+08    10707  2.443570e+08 2022-09-18  1469.404359  204359
# 3  2.609486e+08    13410  3.697855e+08 2022-09-19  1334.321067  204053
# 4  2.540213e+08    11117  3.349061e+08 2022-09-20  1375.641442  204440
#
#          close
# 0  1433.463152
# 1  1469.404359
# 2  1334.321067
# 3  1375.641442
# 4  1322.192169

# %%
df = df.drop(columns=["id"])
df = df.set_index(['date'])
df.head()
# Out:
#                    high          low        tvlUSD  txCount     volumeUSD  \
# date
# 2022-09-16  1483.170696  1396.900687  2.517911e+08    11053  4.784684e+08
# 2022-09-17  1476.144985  1402.098845  2.666791e+08     9014  2.088181e+08
# 2022-09-18  1469.421851  1324.864844  2.485486e+08    10707  2.443570e+08
# 2022-09-19  1392.051034  1274.907911  2.609486e+08    13410  3.697855e+08
# 2022-09-20  1383.911802  1313.997663  2.540213e+08    11117  3.349061e+08
#
#                    open    tick        close
# date
# 2022-09-16  1472.111248  203641  1433.463152
# 2022-09-17  1433.463152  203394  1469.404359
# 2022-09-18  1469.404359  204359  1334.321067
# 2022-09-19  1334.321067  204053  1375.641442
# 2022-09-20  1375.641442  204440  1322.192169

# %%
import plotly.graph_objects as go

fig = go.Figure(data=[go.Candlestick(x=df.index,
                                     open=df['open'],
                                     high=df['high'],
                                     low=df['low'],
                                     close=df['close'])])
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b9388f70-5b41-46a6-9738-6abdff9b18cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b9388f70-5b41-46a6-9738-6abdff9b18cd")) {                    Plotly.newPlot(                        "b9388f70-5b41-46a6-9738-6abdff9b18cd",                        [{"close":[1433.4631515261938,1469.4043591714062,1334.3210668168465,1375.6414418561278,1322.1921693346671,1246.55102393471,1326.5421050299713,1327.583336213949,1317.6350886948305,1294.1076624494317,1336.4113680454032,1328.6472894260633,1337.1102694696908,1336.4099210054073,1328.5729041814202,1311.1734032586453,1277.1549895567503,1323.7052233697948,1361.7440096520627,1352.6519479756146,1351.8952646433006,1331.5003840411457,1313.7694393196596,1322.8216538868974,1290.2031272583565,1279.2316046181018,1294.4066239494748,1287.4529240920535,1297.4054210153186,1274.2602752145647,1306.1004488475317,1331.319365021017,1310.2065158230241,1285.281206845382,1282.739321559561,1299.8858722609307,1313.5798969069112,1363.738888336176,1344.4204061845367,1461.3893785306252,1566.7331329892454,1513.4835217949903,1555.42222765187,1620.1519449697496,1590.5618353921284,1573.4780267799622,1591.971294388107,1519.1589205098126,1530.8637746777033,1645.1536476216352,1627.1376220164357,1568.8871735696648,1568.06546432969,1334.0539006347674,1099.7250423266798,1295.2874897779468,1285.9885783807204,1254.1605236734401,1219.872643757742,1240.977833496094,1251.6326615959865,1215.355072058014,1198.9528155974276,1211.932477767782,1216.844597378877,1140.497107701902,1106.9685382555838,1137.5441785477537,1184.0581088713423,1203.2721213544762,1197.9486615411665,1204.966554427664,1191.450950382376,1167.9403772760775,1216.0354394400479,1294.849159093892,1275.4826876853265,1295.089709459369,1241.186876042802,1280.1689393920913,1259.809025631571,1271.5328608398438,1231.5059002599965,1280.5640123831436,1262.2799212646487,1265.9022980736208,1263.2121073091614,1275.3802545937278,1320.7311254347321,1307.5027413309017,1266.1248641580603,1167.4993961403661,1186.9491040388393,1183.0350138245346,1167.093919309262,1217.4099385436036,1214.0059941202448,1217.2907096120778,1219.9536761853683,1220.930623564374,1218.309494251504,1227.4594266044267,1211.4765187625133,1189.569392826188,1200.6814904704147,1198.8253243820861,1195.5839948533555,1199.7817218216985,1213.6934249197689,1214.1442907974645,1256.0588481926563,1250.2496519046645,1269.0408301069056,1263.5329225350383,1289.0454396406665,1321.008788470793,1335.4333965009832,1389.5776650297291,1416.5449361980109,1451.255874502207,1550.441081755956,1552.7026089664344,1576.5237832552575,1565.1380823831123,1511.320835491202,1551.9401641154145,1659.544375465029,1626.0195057179221,1627.8464443270461,1626.820921735898,1554.721374912468,1614.8008505438047,1602.0401028136987,1597.6280106294612,1573.1607760778131,1645.6284729740908,1566.2536801178408,1586.1482626723703,1641.7269365604143,1643.5995223893378,1664.668230487312,1666.9482495898603,1630.215818804121,1613.872987164238,1672.8381771616803,1649.997123304495,1544.5466983885813,1513.3415200931197,1538.9987372508062,1515.5027535611339,1506.8547671533242,1557.485008964664,1676.1683370999685,1638.6054532408596,1694.5673955731736,1692.6068638576864,1681.052007085757,1704.0300491381224,1659.0078348130544,1643.8449300762518,1650.6081582444288,1608.2849476252509,1595.3486289827017,1641.3506104032035,1634.0423194806447,1604.5035931017792,1665.2294039414182,1647.248931393667,1568.6024368769338,1566.2963366022998,1564.4861931700425,1566.0352565045746,1562.0752375775428,1531.8501400016369,1436.3981495770015,1439.4676224535228,1537.219889222437,1603.9502889819407,1680.2262756174057,1705.8679833675153,1655.246315878678,1677.7580484544183,1791.9787060 ...

# %%
dataset = df.values
dataset
# Out:
# array([[1.48317070e+03, 1.39690069e+03, 2.51791059e+08, ...,
#         1.47211125e+03, 2.03641000e+05, 1.43346315e+03],
#        [1.47614498e+03, 1.40209885e+03, 2.66679134e+08, ...,
#         1.43346315e+03, 2.03394000e+05, 1.46940436e+03],
#        [1.46942185e+03, 1.32486484e+03, 2.48548636e+08, ...,
#         1.46940436e+03, 2.04359000e+05, 1.33432107e+03],
#        ...,
#        [1.91744262e+03, 1.87164646e+03, 4.21586684e+08, ...,
#         1.89410228e+03, 2.00821000e+05, 1.90038819e+03],
#        [1.90651873e+03, 1.85254812e+03, 4.21238435e+08, ...,
#         1.90038819e+03, 2.00893000e+05, 1.88681227e+03],
#        [1.90372155e+03, 1.87535372e+03, 4.25635507e+08, ...,
#         1.88681227e+03, 2.00841000e+05, 0.00000000e+00]])

# %%
dataset.shape
# Out:
# (419, 8)

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
dataset = scaler.fit_transform(dataset)

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset)-look_back-1):
        a = dataset[i:(i+look_back)]
        dataX.append(a)
        dataY.append(dataset[i+look_back,[0,1,7]]) #predict high, low, and close
    return numpy.array(dataX), numpy.array(dataY)

# %%
train_size = int(len(dataset) * 0.7)
test_size = len(dataset) - train_size
train, test = dataset[0:train_size,:], dataset[train_size:len(dataset),:]

# %%
look_back = 4
trainX, trainY = create_dataset(train, look_back)
testX, testY = create_dataset(test, look_back)

# %%
print(trainX.shape)
print(trainY.shape)
# Out:
# (288, 4, 8)
# (288, 3)

# %%
trainX = numpy.reshape(trainX, (trainX.shape[0], trainX.shape[1], trainX.shape[2]))
testX = numpy.reshape(testX, (testX.shape[0], testX.shape[1], testX.shape[2]))

# %%
batch_size = 1
model0 = Sequential()
model0.add(LSTM(6, batch_input_shape=(batch_size, look_back, 8), stateful=True, return_sequences=False))
model0.add(Dense(3))
model0.compile(loss='mean_squared_error', optimizer='adam')

# %%
train_loss_history = []
test_loss_history = []

for i in range(25):
    history = model0.fit(trainX, trainY, epochs=10, batch_size=batch_size, verbose=2, shuffle=False)
    train_loss_history.extend(history.history['loss'])

    test_loss = model0.evaluate(testX, testY, batch_size=batch_size)
    test_loss_history.append(test_loss)


    # Reset states for the next iteration
    model0.reset_states()
# Out:
# Epoch 1/10
# 288/288 - 6s - loss: 0.0314 - 6s/epoch - 20ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0130 - 1s/epoch - 5ms/step
# Epoch 3/10
# 288/288 - 2s - loss: 0.0064 - 2s/epoch - 5ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0050 - 1s/epoch - 5ms/step
# Epoch 5/10
# 288/288 - 2s - loss: 0.0045 - 2s/epoch - 6ms/step
# Epoch 6/10
# 288/288 - 2s - loss: 0.0041 - 2s/epoch - 9ms/step
# Epoch 7/10
# 288/288 - 2s - loss: 0.0038 - 2s/epoch - 7ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0036 - 1s/epoch - 5ms/step
# Epoch 9/10
# 288/288 - 2s - loss: 0.0034 - 2s/epoch - 5ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0032 - 1s/epoch - 5ms/step
# 121/121 [==============================] - 2s 4ms/step - loss: 0.0035
# Epoch 1/10
# 288/288 - 2s - loss: 0.0030 - 2s/epoch - 7ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0028 - 838ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0027 - 1s/epoch - 4ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0026 - 1s/epoch - 4ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0024 - 1s/epoch - 4ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0023 - 1s/epoch - 4ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0022 - 768ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0021 - 802ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0020 - 774ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0019 - 754ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0020
# Epoch 1/10
# 288/288 - 1s - loss: 0.0018 - 769ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0017 - 774ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0017 - 814ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0016 - 776ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0016 - 770ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0016 - 767ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0015 - 766ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0015 - 876ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0015 - 1s/epoch - 4ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0015 - 1s/epoch - 4ms/step
# 121/121 [==============================] - 1s 4ms/step - loss: 0.0015
# Epoch 1/10
# 288/288 - 2s - loss: 0.0015 - 2s/epoch - 5ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0014 - 1s/epoch - 5ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0014 - 1s/epoch - 4ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0014 - 1s/epoch - 5ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0014 - 1s/epoch - 4ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0014 - 1s/epoch - 4ms/step
# Epoch 7/10
# 288/288 - 2s - loss: 0.0014 - 2s/epoch - 6ms/step
# Epoch 8/10
# 288/288 - 2s - loss: 0.0014 - 2s/epoch - 9ms/step
# Epoch 9/10
# 288/288 - 2s - loss: 0.0014 - 2s/epoch - 7ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0014 - 1s/epoch - 4ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0014
# Epoch 1/10
# 288/288 - 1s - loss: 0.0014 - 818ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0014 - 818ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0013 - 824ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0013 - 1s/epoch - 4ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0013 - 1s/epoch - 4ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0013 - 1s/epoch - 4ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0013 - 1s/epoch - 4ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0013 - 784ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0013 - 772ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0013 - 789ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0013
# Epoch 1/10
# 288/288 - 1s - loss: 0.0013 - 845ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0013 - 814ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0013 - 791ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0013 - 761ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0013 - 740ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0013 - 782ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0013 - 770ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0013 - 933ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0013 - 1s/epoch - 4ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0013 - 1s/epoch - 4ms/step
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0012
# Epoch 1/10
# 288/288 - 1s - loss: 0.0013 - 996ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0013 - 784ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0013 - 762ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0013 - 773ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0013 - 745ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0013 - 736ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0013 - 751ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0013 - 751ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0013 - 814ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0012 - 763ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0012
# Epoch 1/10
# 288/288 - 1s - loss: 0.0012 - 881ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0012 - 906ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0012 - 759ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0012 - 803ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0012 - 796ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0012 - 746ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0012 - 762ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 1/10
# 288/288 - 1s - loss: 0.0012 - 727ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0012 - 725ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0012 - 739ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0012 - 746ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0012 - 747ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0012 - 744ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0012 - 736ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 9/10
# 288/288 - 2s - loss: 0.0012 - 2s/epoch - 8ms/step
# Epoch 10/10
# 288/288 - 2s - loss: 0.0012 - 2s/epoch - 7ms/step
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 1/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0012 - 771ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0012 - 760ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0012 - 763ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0012 - 750ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0012 - 716ms/epoch - 2ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0012 - 810ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0012 - 705ms/epoch - 2ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0012 - 749ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 1/10
# 288/288 - 1s - loss: 0.0012 - 732ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0012 - 742ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0012 - 788ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0012 - 759ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0012 - 799ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0012 - 747ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 1/10
# 288/288 - 1s - loss: 0.0012 - 729ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0012 - 810ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0012 - 760ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0012 - 754ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0012 - 740ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0012 - 769ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0012 - 762ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0012 - 752ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0012 - 720ms/epoch - 2ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0012 - 1s/epoch - 4ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 1/10
# 288/288 - 1s - loss: 0.0012 - 745ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0012 - 751ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0012 - 750ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0012 - 737ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0012 - 765ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0012 - 758ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 758ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 779ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 782ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 747ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0011
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 753ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 758ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 735ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 711ms/epoch - 2ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 746ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 746ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 734ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 759ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0011
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 810ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 891ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 721ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 754ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 731ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 771ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 787ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 746ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 723ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 797ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 764ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 881ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# 121/121 [==============================] - 0s 3ms/step - loss: 0.0010
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 767ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 742ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 756ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 713ms/epoch - 2ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 787ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 767ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 771ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 734ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 757ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 765ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 746ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 790ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 891ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 880ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 785ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 788ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 745ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 0.0010
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 702ms/epoch - 2ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 744ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 741ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 755ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 755ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 717ms/epoch - 2ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 723ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 708ms/epoch - 2ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 735ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 9.9437e-04
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 805ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 747ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 717ms/epoch - 2ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 753ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 713ms/epoch - 2ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 735ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 723ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 748ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 738ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 741ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 3ms/step - loss: 9.8945e-04
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 920ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 764ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 823ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 749ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 764ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 742ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 761ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 756ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 741ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 9.8607e-04
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 752ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 794ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 754ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 999ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0011 - 1s/epoch - 4ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0011 - 785ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0011 - 805ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0011 - 827ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 9.8284e-04
# Epoch 1/10
# 288/288 - 1s - loss: 0.0011 - 792ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0011 - 782ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0011 - 782ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0011 - 776ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0011 - 743ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0010 - 735ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0010 - 726ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0010 - 725ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0010 - 739ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0010 - 1s/epoch - 4ms/step
# 121/121 [==============================] - 0s 4ms/step - loss: 9.7905e-04
# Epoch 1/10
# 288/288 - 1s - loss: 0.0010 - 1s/epoch - 4ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0010 - 1s/epoch - 4ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0010 - 917ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0010 - 785ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0010 - 812ms/epoch - 3ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0010 - 777ms/epoch - 3ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0010 - 797ms/epoch - 3ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0010 - 762ms/epoch - 3ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0010 - 755ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0010 - 778ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 9.7439e-04
# Epoch 1/10
# 288/288 - 1s - loss: 0.0010 - 778ms/epoch - 3ms/step
# Epoch 2/10
# 288/288 - 1s - loss: 0.0010 - 801ms/epoch - 3ms/step
# Epoch 3/10
# 288/288 - 1s - loss: 0.0010 - 853ms/epoch - 3ms/step
# Epoch 4/10
# 288/288 - 1s - loss: 0.0010 - 837ms/epoch - 3ms/step
# Epoch 5/10
# 288/288 - 1s - loss: 0.0010 - 1s/epoch - 4ms/step
# Epoch 6/10
# 288/288 - 1s - loss: 0.0010 - 1s/epoch - 4ms/step
# Epoch 7/10
# 288/288 - 1s - loss: 0.0010 - 1s/epoch - 4ms/step
# Epoch 8/10
# 288/288 - 1s - loss: 0.0010 - 1s/epoch - 4ms/step
# Epoch 9/10
# 288/288 - 1s - loss: 0.0010 - 749ms/epoch - 3ms/step
# Epoch 10/10
# 288/288 - 1s - loss: 0.0010 - 808ms/epoch - 3ms/step
# 121/121 [==============================] - 0s 2ms/step - loss: 9.6879e-04

# %%
model0.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (1, 6)                    360
#
#  dense (Dense)               (1, 3)                    21
#
# =================================================================
# Total params: 381 (1.49 KB)
# Trainable params: 381 (1.49 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

def calculate_metrics(true, predicted):
    mse = mean_squared_error(true, predicted)
    rmse = np.sqrt(mse)
    mae = mean_absolute_error(true, predicted)
    r2 = r2_score(true, predicted)
    return {"MSE": mse, "RMSE": rmse, "MAE": mae, "R2": r2}

# high value metrics
testPredict = model0.predict(testX, batch_size=batch_size)
calculate_metrics(testY[:, 0], testPredict[:testY.shape[0], 0])
# Out:
# 121/121 [==============================] - 1s 2ms/step
# {'MSE': 0.001682503689724899,
#  'RMSE': 0.04101833358054541,
#  'MAE': 0.036118103979670343,
#  'R2': 0.8861751462427283}

# %%
date_index = train_size
plt.figure(figsize=(20, 10))
plt.plot(dataset[:,0], color = 'black', label = 'High Price')
plt.plot(range(date_index, date_index + len(testPredict)), testPredict[:, 0], color = 'green', label = 'Predicted High Price')
plt.title('USDC-ETH Price Prediction')
plt.xlabel('Time')
plt.ylabel('USDC-ETH Price')
plt.legend()
plt.show()

# %%
plt.plot(train_loss_history, label='Training Loss')
plt.plot(test_loss_history, label='Test Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss')
plt.legend()
plt.show()

# %%
#testY=testY.reshape(-1,1)
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], 0])
plt.plot(testY[:, 0])
plt.title('Original high vs predicted high', fontsize=15)
plt.show()

# %%
trainPredict = model0.predict(trainX, batch_size=batch_size)
trainScore = math.sqrt(mean_squared_error(trainX[:, -1, 0], trainPredict[:, -1, 0]))
print('Train Score of high value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(trainX[:, -1, 1], trainPredict[:, -1, 1]))
print('Train Score of low value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(trainX[:, -1, 2], trainPredict[:, -1, 2]))
print('Train Score of close value: %.10f RMSE' % (trainScore))
model0.reset_states()
# Out:
# 288/288 [==============================] - 1s 2ms/step
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-20-7edc89a5ba1b> in <cell line: 2>()
#       1 trainPredict = model0.predict(trainX, batch_size=batch_size)
# ----> 2 trainScore = math.sqrt(mean_squared_error(trainX[:, -1, 0], trainPredict[:, -1, 0]))
#       3 print('Train Score of high value: %.10f RMSE' % (trainScore))
#       4 trainScore = math.sqrt(mean_squared_error(trainX[:, -1, 1], trainPredict[:, -1, 1]))
#       5 print('Train Score of low value: %.10f RMSE' % (trainScore))
#
# IndexError: too many indices for array: array is 2-dimensional, but 3 were indexed

# %%
testPredict = model0.predict(testX, batch_size=batch_size)
testScore = math.sqrt(mean_squared_error(testY[:, -1, 0], testPredict[0:testY.shape[0], -1, 0]))
print('Test Score of high value: %.10f RMSE' % (testScore))
trainScore = math.sqrt(mean_squared_error(testY[:, -1, 1], testPredict[0:testY.shape[0], -1, 1]))
print('Test Score of low value: %.10f RMSE' % (trainScore))
trainScore = math.sqrt(mean_squared_error(testY[:, -1, 2], testPredict[0:testY.shape[0], -1, 2]))
print('Test Score of close value: %.10f RMSE' % (trainScore))

# %%
print(trainPredict.shape)
print(trainY.shape)

# %%
print(testPredict.shape)
print(testY.shape)

# %%
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], -1, 1])
plt.plot(testY[:, -1, 1])
plt.title('Original low vs predicted low', fontsize=15)
plt.show()

# %%
#testY=testY.reshape(-1,1)
plt.figure(figsize=(10, 10))
plt.plot(testPredict[0:testY.shape[0], -1, 2])
plt.plot(testY[:, -1, 2])
plt.title('Original close vs predicted close', fontsize=15)
plt.show()
